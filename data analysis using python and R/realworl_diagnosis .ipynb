# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('/content/Airtel Prepaid.csv')
print(data.head())
# Out:
#    Price  Data(GB) per Day  Data(GB)  Days        Additional Benefits
# 0   3359               2.5         0   365    Disney + Hotstar 1 year
# 1   2999               2.0         0   365                          0
# 2    999               2.5         0    84    Amazon prime membership
# 3    839               2.0         0    84  Disney + Hotstar 3 Months
# 4    719               1.5         0    84                          0

# %%
high_prices=data[data['Price']>1500]
if not high_prices.empty:
  print("high pricess")
  print(high_prices)
# Out:
# high pricess
#     Price  Data(GB) per Day  Data(GB)  Days      Additional Benefits
# 0    3359               2.5         0   365  Disney + Hotstar 1 year
# 1    2999               2.0         0   365                        0
# 26   3359               2.5         0   365  Disney + Hotstar 1 year
# 27   1799               0.0        24   365                        0

# %%
data_use=data[data['Data(GB) per Day']<2.0]
if not data_use.empty:
  print("data use")
  print(data_use)
# Out:
# data use
#     Price  Data(GB) per Day  Data(GB)  Days Additional Benefits
# 4     719               1.5         0    84                   0
# 6     666               1.5         0    77                   0
# 10    479               1.5         0    56                   0
# 11    455               0.0         6    84                   0
# 15    299               1.5         0    28                   0
# 16    296               0.0        25    30                   0
# 17    265               1.0         0    28     Free hellotunes
# 18    239               1.0         0    24     Free hellotunes
# 19    209               1.0         0    21     Free hellotunes
# 21    155               1.0         0    24     Free hellotunes
# 27   1799               0.0        24   365                   0

# %%
import pandas as pd
data=pd.read_csv('/content/Airtel Prepaid.csv')
data=data[data['Data(GB)']>0]
if not data.empty:
  print("data use")
  print(data)
# Out:
# data use
#     Price  Data(GB) per Day  Data(GB)  Days Additional Benefits
# 11    455               0.0         6    84                   0
# 16    296               0.0        25    30                   0
# 27   1799               0.0        24   365                   0

# %%
days_usages=data[data['Days']<100]
if not days_usages.empty:
  print("data use")
  print(data)
# Out:
# data use
#     Price  Data(GB) per Day  Data(GB)  Days Additional Benefits
# 11    455               0.0         6    84                   0
# 16    296               0.0        25    30                   0

# %%
Benefits=data[data['Days']>0]
if not  Benefits.empty:
  print("data use")
  print(data)
# Out:
# data use
#     Price  Data(GB) per Day  Data(GB)  Days Additional Benefits
# 11    455               0.0         6    84                   0
# 16    296               0.0        25    30                   0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data_original = pd.read_csv('/content/Airtel Prepaid.csv')
sns.scatterplot(data=data_original, x='Days', y='Price')
plt.title('Price vs. Days for Prepaid Plans')
plt.xlabel('Days')
plt.ylabel('Price')
plt.grid(True)
plt.show()
