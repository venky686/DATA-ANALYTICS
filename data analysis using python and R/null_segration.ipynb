# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
from google.colab import files
uploaded = files.upload()
df=pd.read_csv('/content/weatherHistory (1).csv')
df.head()
df.info()
# Out:
#      <input type="file" id="files-b08c28e7-4c27-4e38-96bd-0a474b7837d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b08c28e7-4c27-4e38-96bd-0a474b7837d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
upload =df.dropna(axis=1)
upload.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            64 non-null     object
#  1   Summary                   64 non-null     object
#  2   Precip Type               64 non-null     object
#  3   Temperature (C)           64 non-null     float64
#  4   Apparent Temperature (C)  64 non-null     float64
#  5   Humidity                  64 non-null     float64
#  6   Wind Speed (km/h)         64 non-null     float64
#  7   Wind Bearing (degrees)    64 non-null     int64
#  8   Visibility (km)           64 non-null     float64
#  9   Pressure (millibars)      64 non-null     float64
#  10  Daily Summary             64 non-null     object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 5.6+ KB

# %%
df['Loud Cover'].mean()
# Out:
# np.float64(1.1956521739130435)

# %%
df['Loud Cover'].median()
# Out:
# 1.0

# %%
try:
    median_loud_cover = df['Loud Cover'].median()
    df['Loud Cover'] = df['Loud Cover'].fillna(median_loud_cover)
    print(f"NaN values in 'Loud Cover' filled with median: {median_loud_cover}")
except KeyError:
    print("Error: 'Loud Cover' column not found in DataFrame.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

df.info()
# Out:
# NaN values in 'Loud Cover' filled with median: 1.0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            64 non-null     object
#  1   Summary                   64 non-null     object
#  2   Precip Type               64 non-null     object
#  3   Temperature (C)           64 non-null     float64
#  4   Apparent Temperature (C)  64 non-null     float64
#  5   Humidity                  64 non-null     float64
#  6   Wind Speed (km/h)         64 non-null     float64
#  7   Wind Bearing (degrees)    64 non-null     int64
#  8   Visibility (km)           64 non-null     float64
#  9   Loud Cover                64 non-null     float64
#  10  Pressure (millibars)      64 non-null     float64
#  11  Daily Summary             64 non-null     object
# dtypes: float64(7), int64(1), object(4)
# ...
