# %% [markdown]
# **variable type**

# %%
a=90.3
b=int(a)
print(round(a))
print(type(a))
print("\n")

c=90
b=float(c)
print(type(b))

a= "90"
r= int(a)
print(type(r))

a= "hello"
print(type(a))

a= "34.67"
b=int(float(a))
print(type(b))
# Out:
# 90
# <class 'float'>
#
#
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'int'>

# %% [markdown]
#  key words

# %%
a=13254
b=13258
if a>b:
  print("a is greater")
else:
  print("b is greater")
# Out:
# b is greater

# %%
def sum(a,b):
  c=a+b

# %%
a = "faaaa"
a_modified = a.replace("f","h")

my_string_variable = "goooo"



print([len(a)-1])
print(len(a))
print(a[::-1])
# Out:
# [4]
# 5
# aaaaf

# %% [markdown]
# **data type**

# %%
tople=(2,3,4,5)
t= 1,2,3,4,5,6,7,8,9
print(type(tople))
print(type(t))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
distonary={1:"hello",2:"world"}
print(type(distonary))
# Out:
# <class 'dict'>

# %%
set={1,2,3}
print(type(set))
# Out:
# <class 'set'>

# %%
list={12,13,14,15,16}
print(type(list))
# Out:
# <class 'set'>

# %%
a= "faaaa"
a.replace("f","h")

list=("goooo")

list.replace("g","h")
print(list)
print([len(a)-1])
print(len(a))
print(a[::-1])
# Out:
# goooo
# [4]
# 5
# aaaaf

# %%
a="saas"
w=list(a)
w[0]="a"
print(w)

# %% [markdown]
# **Operators**

# %%
def sum__array(a,b):
  c=a+b
  d=a-b
  e=a*b
  f=a**b
  g=a%b
  h=a//b
  i=a/b
  print(i)
  print(h)
  print(g)
  print(d)
  print(e)
  print(f)
  print(c)

# %%
sum__array(10,8)
# Out:
# 1.25
# 1
# 2
# 2
# 80
# 100000000
# 18

# %%
print(2+(10+13)*2**2-45//4)
print(12435%(10+13)*2**13999-45//4)
# Out:
# 83
# ...

# %%
print(4+(8**2)-3**2%1)
print(4%(10-1)**2-60//(7+2))
# Out:
# 68
# -2

# %%
a=2
b="3"
print(a+int(b))
# Out:
# 5

# %% [markdown]
# ***Lib_python***

# %%
list= [["a"],2.0,23,["b","23","23.23"]]
print(type(list))
print(list[3][1])
print(23 in list)
print(list[-1][-2])
# Out:
# <class 'list'>
# 23
# True
# 23

# %%
a="my name"
b="is jof"
c=a+b
print(c*3)
print(c)
# Out:
# my nameis jofmy nameis jofmy nameis jof
# my nameis jof

# %%
list=[1,2,3,4,5]
list.append([6,7,8])
len(list)
print(list)
# Out:
# [1, 2, 3, 4, 5, [6, 7, 8]]

# %%
del(list[0])
print(list)
# Out:
# [3, 4, 5, [6, 7, 8]]

# %%
list.pop(2)
print(list)
# Out:
# [1, 3]

# %%
a=["a","c","b"]
a.sort()
print(a)
# Out:
# ['a', 'b', 'c']

# %%
a=["a","c","b"]
a.sort(reverse=True)
print(a)
# Out:
# ['c', 'b', 'a']

# %%
a="kumar"
b="ravi"
c="003"
print(a+" " +b+" "+c)
a=("kumar_ravi_003")
b=a.split("_")
print(b)
# Out:
# kumar ravi 003
# ['kumar', 'ravi', '003']

# %%
a=[12,4,5,(1,5,6)]
b=[2,33,222,14,25]
print(b[-5])
word=["1","2","3","4","5"]
word[:]=[]
print(word)
l=["one","two","three","four","five","six"]
print(sorted(l))
print(l)
# Out:
# 2
# []
# ['five', 'four', 'one', 'six', 'three', 'two']
# ['one', 'two', 'three', 'four', 'five', 'six']
