# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics

# %%
from google.colab import drive
from google.colab import files
uploaded = files.upload()
df=pd.read_csv('/content/cleaned_global_water_consumption (1).csv')
df.head()
df.info()
# Out:
#      <input type="file" id="files-c7c86267-d58c-4a33-942e-994a652c660f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c7c86267-d58c-4a33-942e-994a652c660f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # New Section

# %%
upload =df.dropna(axis=1)
upload.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 8 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Row Labels                                             54 non-null     int64
#  1   Average of Agricultural Water Use (%)                  54 non-null     float64
#  2   Count of Country                                       54 non-null     int64
#  3   Average of Per Capita Water Use (Liters per Day)       54 non-null     float64
#  4   Sum of Total Water Consumption (Billion Cubic Meters)  54 non-null     float64
#  5   Max of Groundwater Depletion Rate (%)                  54 non-null     float64
#  6   Sum of Rainfall Impact (Annual Precipitation in mm)    54 non-null     float64
#  7   Average of Industrial Water Use (%)                    54 non-null     float64
# dtypes: float64(6), int64(2)
# ...

# %%
df['Average of Agricultural Water Use (%)'].mean()
# Out:
# np.float64(75.29094276296294)

# %%
df['Average of Agricultural Water Use (%)'].median()
# Out:
# 75.17983165

# %%
try:
    median_loud_cover = df['Average of Agricultural Water Use (%)'].median()
    df['Average of Agricultural Water Use (%)'] = df['Average of Agricultural Water Use (%)'].fillna(median_loud_cover)
    print(f"NaN values in 'Loud Cover' filled with median: {median_loud_cover}")
except KeyError:
    print("Error: 'Loud Cover' column not found in DataFrame.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

df.info()
# Out:
# NaN values in 'Loud Cover' filled with median: 75.17983165
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 25 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Row Labels                                             54 non-null     int64
#  1   Average of Agricultural Water Use (%)                  54 non-null     float64
#  2   Count of Country                                       54 non-null     int64
#  3   Average of Per Capita Water Use (Liters per Day)       54 non-null     float64
#  4   Sum of Total Water Consumption (Billion Cubic Meters)  54 non-null     float64
#  5   Max of Groundwater Depletion Rate (%)                  54 non-null     float64
#  6   Sum of Rainfall Impact (Annual Precipitation in mm)    54 non-null     float64
# ...

# %%
try:
    median_loud_cover = df['Average of Agricultural Water Use (%)'].mean()
    df['Average of Agricultural Water Use (%)'] = df['Average of Agricultural Water Use (%)'].fillna(median_loud_cover)
    print(f"NaN values in 'Loud Cover' filled with median: {median_loud_cover}")
except KeyError:
    print("Error: 'Loud Cover' column not found in DataFrame.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")

df.info()
# Out:
# NaN values in 'Loud Cover' filled with median: 75.29094276296294
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 25 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   Row Labels                                             54 non-null     int64
#  1   Average of Agricultural Water Use (%)                  54 non-null     float64
#  2   Count of Country                                       54 non-null     int64
#  3   Average of Per Capita Water Use (Liters per Day)       54 non-null     float64
#  4   Sum of Total Water Consumption (Billion Cubic Meters)  54 non-null     float64
#  5   Max of Groundwater Depletion Rate (%)                  54 non-null     float64
#  6   Sum of Rainfall Impact (Annual Precipitation in mm)    54 non-null     float64
# ...

# %%
df['Average of Agricultural Water Use (%)'].min()-df['Average of Agricultural Water Use (%)'].max()
# Out:
# -53.93760947999999

# %%
df['Average of Agricultural Water Use (%)'].std()
# Out:
# 15.573188434125253

# %%
df['Average of Agricultural Water Use (%)'].std(ddof=0)
# Out:
# 15.428318416238119

# %%
df['Average of Agricultural Water Use (%)'].var()
# Out:
# 242.52419800477253

# %%
df['Average of Agricultural Water Use (%)'].var(ddof=0)
# Out:
# 238.0330091528323

# %%
QI=df['Average of Agricultural Water Use (%)'].quantile(0.75)
qi2=df['Average of Agricultural Water Use (%)'].quantile(0.25)
Q3=df['Average of Agricultural Water Use (%)'].quantile(0.50)
Q=QI-qi2
print(Q3)
print(QI)
print(qi2)
print(Q)
# Out:
# 75.17983165
# 88.42983165
# 61.92983165
# 26.5

# %%
meandeviation=(df['Average of Agricultural Water Use (%)'] - df['Average of Agricultural Water Use (%)'].mean()).abs().mean()
print(meandeviation)
# Out:
# 13.388888890740743
